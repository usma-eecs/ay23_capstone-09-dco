# %%
from elasticsearch import Elasticsearch
import elasticsearch.helpers
from elasticsearch_dsl import Search
import pandas as pd
import urllib3
import json
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# %%
es = Elasticsearch(['https://10.19.89.215:9200'],
ca_certs=False,verify_certs=False, http_auth=('jupyter','B3@+Navy!!'))
searchContext = Search(using=es, index='*:so-*', doc_type='doc')
# Out:
# C:\Users\Michael Grimm\anaconda3\lib\site-packages\elasticsearch\connection\http_urllib3.py:209: UserWarning: Connecting to https://10.19.89.215:9200 using SSL with verify_certs=False is insecure.
#   warnings.warn(

# %%
# ourGen = elasticsearch.helpers.scan(
#     es,
#     query = 'event.module:kibana',
#     scroll = '100m',
#     preserve_order = False,
#     size = 100,
#     request_timeout = None,
#     clear_scroll = True
# )
# an example of using elasticsearch.helpers to create a generator

# %%
s = searchContext.query('query_string', query='event.dataset: alert')
# s = s.source(['metadata','agent','process','@timestamp','transaction'])

# %%
response = s.execute()

if response.success():
  df = pd.DataFrame((d.to_dict() for d in s.scan()))
df
# Out:
# C:\Users\Michael Grimm\anaconda3\lib\site-packages\elasticsearch_dsl\search.py:715: ElasticsearchWarning: The client is unable to verify that the server is Elasticsearch due security privileges on the server side
#   self, es.search(index=self._index, body=self.to_dict(), **self._params)
#                                                  metadata  \
# 0       {'beat': 'filebeat', 'ip_address': '172.17.0.1...
# 1       {'beat': 'filebeat', 'ip_address': '172.17.0.1...
# 2       {'beat': 'filebeat', 'ip_address': '172.17.0.1...
# 3       {'beat': 'filebeat', 'ip_address': '172.17.0.1...
# 4       {'beat': 'filebeat', 'ip_address': '172.17.0.1...
# ...                                                   ...
# 161311  {'pipeline': 'ossec', 'beat': 'filebeat', 'ip_...
# 161312  {'pipeline': 'ossec', 'beat': 'filebeat', 'ip_...
# 161313  {'pipeline': 'ossec', 'beat': 'filebeat', 'ip_...
# 161314  {'pipeline': 'ossec', 'beat': 'filebeat', 'ip_...
# 161315  {'pipeline': 'ossec', 'beat': 'filebeat', 'ip_...
#
#                                                       log  \
# 0       {'file': {'path': '/nsm/suricata/eve-2022-09-2...
# 1       {'file': {'path': '/nsm/suricata/eve-2022-09-3...
# 2       {'file': {'path': '/nsm/suricata/eve-2022-10-0...
# 3       {'file': {'path': '/nsm/suricata/eve-2022-10-0...
# 4       {'file': {'path': '/nsm/suricata/eve-2022-10-0...
# ...                                                   ...
# 161311  {'file': {'path': '/wazuh/archives/archives.js...
# 161312  {'file': {'path': '/wazuh/archives/archives.js...
# 161313  {'file': {'path': '/wazuh/archives/archives.js...
# 161314  {'file': {'path': '/wazuh/archives/archives.js...
# 161315  {'file': {'path': '/wazuh/archives/archives.js...
#
#                                 destination  \
# 0          {'port': 0, 'ip': '10.3.94.254'}
# 1       {'port': 7680, 'ip': '10.10.2.168'}
# 2          {'port': 0, 'ip': '10.3.94.254'}
# 3          {'port': 0, 'ip': '10.3.94.254'}
# 4          {'port': 0, 'ip': '10.3.94.254'}
# ...                                     ...
# 161311                                  NaN
# 161312                                  NaN
# 161313                                  NaN
# 161314                                  NaN
# 161315                                  NaN
#
#                                                      rule  \
# 0       {'severity': 3, 'reference': 'https://doc.emer...
# 1       {'severity': 3, 'reference': 'https://doc.emer...
# 2       {'severity': 3, 'reference': 'https://doc.emer...
# 3       {'severity': 3, 'reference': 'https://doc.emer...
# 4       {'severity': 3, 'reference': 'https://doc.emer...
# ...                                                   ...
# 161311  {'firedtimes': 5, 'mail': False, 'level': 3, '...
# 161312  {'firedtimes': 4, 'mail': False, 'level': 3, '...
# 161313  {'firedtimes': 7, 'mail': False, 'level': 3, '...
# 161314  {'mail': False, 'level': 5, 'pci_dss': ['11.5'...
# 161315  {'mail': True, 'level': 7, 'pci_dss': ['11.5']...
#
#                                      source  \
# 0          {'port': 0, 'ip': '10.3.94.250'}
# 1       {'port': 49184, 'ip': '10.19.89.6'}
# 2          {'port': 0, 'ip': '10.3.94.250'}
# 3          {'port': 0, 'ip': '10.3.94.250'}
# 4          {'port': 0, 'ip': '10.3.94.250'}
# ...                                     ...
# 161311                                  NaN
# 161312                                  NaN
# 161313                                  NaN
# 161314                                  NaN
# 161315                                  NaN
#
#                                                   network  \
# 0       {'community_id': '1:Ga0HRBs8DG52vzntOnMmCu4URa...
# 1       {'community_id': '1:Odo/zFKiLaeO3wl30vAbZlJArE...
# 2       {'community_id': '1:Ga0HRBs8DG52vzntOnMmCu4URa...
# 3       {'community_id': '1:Ga0HRBs8DG52vzntOnMmCu4URa...
# 4       {'community_id': '1:Ga0HRBs8DG52vzntOnMmCu4URa...
# ...                                                   ...
# 161311                                                NaN
# 161312                                                NaN
# 161313                                                NaN
# 161314                                                NaN
# 161315                                                NaN
#
#                     observer                   ecs @version  \
# 0       {'name': 'seconion'}  {'version': '8.0.0'}        1
# 1       {'name': 'seconion'}  {'version': '8.0.0'}        1
# 2       {'name': 'seconion'}  {'version': '8.0.0'}        1
# 3       {'name': 'seconion'}  {'version': '8.0.0'}        1
# 4       {'name': 'seconion'}  {'version': '8.0.0'}        1
# ...                      ...                   ...      ...
# 161311                   NaN  {'version': '8.0.0'}        1
# 161312                   NaN  {'version': '8.0.0'}        1
# 161313                   NaN  {'version': '8.0.0'}        1
# 161314                   NaN  {'version': '8.0.0'}        1
# 161315                   NaN  {'version': '8.0.0'}        1
#
#                                                      host  ...  \
# 0                                    {'name': 'seconion'}  ...
# 1                                    {'name': 'seconion'}  ...
# 2                                    {'name': 'seconion'}  ...
# 3                                    {'name': 'seconion'}  ...
# 4                                    {'name': 'seconion'}  ...
# ...                                                   ...  ...
# 161311                               {'name': 'seconion'}  ...
# 161312                               {'name': 'seconion'}  ...
# 161313                               {'name': 'seconion'}  ...
# 161314  {'syscheck': {'uname_after': 'root', 'mtime_af...  ...
# 161315  {'syscheck': {'size_before': '24045', 'uname_a...  ...
#
#                                      tags                @timestamp  \
# 0       [beats_input_codec_plain_applied]  2022-09-29T23:59:44.735Z
# 1       [beats_input_codec_plain_applied]  2022-09-30T23:59:27.496Z
# 2       [beats_input_codec_plain_applied]  2022-10-01T23:59:47.417Z
# 3       [beats_input_codec_plain_applied]  2022-10-02T23:59:48.048Z
# 4       [beats_input_codec_plain_applied]  2022-10-03T23:59:53.372Z
# ...                                   ...                       ...
# 161311  [beats_input_codec_plain_applied]  2022-10-05T18:39:07.769Z
# 161312  [beats_input_codec_plain_applied]  2022-10-05T18:39:07.769Z
# 161313  [beats_input_codec_plain_applied]  2022-10-05T18:39:07.769Z
# 161314  [beats_input_codec_plain_applied]  2022-10-04T17:15:59.283Z
# 161315  [beats_input_codec_plain_applied]  2022-10-04T17:15:59.283Z
#
#        destination_geo source_geo  \
# 0                  NaN        NaN
# 1                  NaN        NaN
# 2                  NaN        NaN
# 3                  NaN        NaN
# 4                  NaN        NaN
# ...                ...        ...
# 161311             NaN        NaN
# 161312             NaN        NaN
# 161313             NaN        NaN
# 161314             NaN        NaN
# 161315             NaN        NaN
#
#                                                     agent  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 161311  {'ip': '10.19.89.215', 'name': 'seconion', 'id...
# 161312  {'ip': '10.19.89.215', 'name': 'seconion', 'id...
# 161313  {'ip': '10.19.89.215', 'name': 'seconion', 'id...
# 161314  {'ip': '10.19.89.215', 'name': 'seconion', 'id...
# 161315  {'ip': '10.19.89.215', 'name': 'seconion', 'id...
#
#                                    manager decoder process  \
# 0                                      NaN     NaN     NaN
# 1                                      NaN     NaN     NaN
# 2                                      NaN     NaN     NaN
# 3                                      NaN     NaN     NaN
# 4                                      NaN     NaN     NaN
# ...                                    ...     ...     ...
# 161311  {'name': 'seconion-wazuh-manager'}      {}     NaN
# 161312  {'name': 'seconion-wazuh-manager'}      {}     NaN
# 161313  {'name': 'seconion-wazuh-manager'}      {}     NaN
# 161314  {'name': 'seconion-wazuh-manager'}      {}     NaN
# 161315  {'name': 'seconion-wazuh-manager'}      {}     NaN
#
#                                                     wazuh user
# 0                                                     NaN  NaN
# 1                                                     NaN  NaN
# 2                                                     NaN  NaN
# 3                                                     NaN  NaN
# 4                                                     NaN  NaN
# ...                                                   ...  ...
# 161311  {'data': {'file': '/etc/ssh/sshd_config', 'tit...  NaN
# 161312  {'data': {'file': '/etc/ssh/sshd_config', 'tit...  NaN
# 161313  {'data': {'file': '/etc/ssh/sshd_config', 'tit...  NaN
# 161314                                                NaN  NaN
# 161315                                                NaN  NaN
#
# [161316 rows x 22 columns]

# %%
#Query that limits the number of items in the table, only works on event.modules though
response = s.execute()
if response.success():
    df = pd.DataFrame(([d['metadata'],d['log'],d['type'],d['event'], d['fileset'],d['message']] for d in s))
df.columns=['MetaData','Log','Type','Event','FileSet','Message']
df

# %%
uniqueDestIPs = df['destination'].value_counts(dropna=True).rename_axis('unique values').to_frame('counts')
uniqueDestIPs
# Out:
#                                                     counts
# unique values
# {'port': 0, 'ip': '10.3.94.254'}                     43594
# {'geo': {'continent_name': 'North America', 're...   21107
# {'geo': {'continent_name': 'North America', 're...   20080
# {'port': 161, 'ip': '10.13.255.50'}                  12038
# {'port': 53, 'ip': '10.13.20.2'}                      7550
# ...                                                    ...
# {'port': 61478, 'ip': '10.10.3.2'}                       1
# {'geo': {'continent_name': 'North America', 're...       1
# {'port': 61441, 'ip': '10.10.3.2'}                       1
# {'geo': {'continent_name': 'North America', 'co...       1
# {'port': 62480, 'ip': '10.10.3.2'}                       1
#
# [1128 rows x 1 columns]

# %%
uniqueDestIPs[:20].plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='unique values'>

# %%
import os  
os.makedirs('~/capstone/dfCSVs', exist_ok=True)  
df.to_csv('~/capstone/dfCSVs/out.csv')
